# %% [markdown]
# # Inside the Decentralised Casino

# %%
# The first step is to load in gamba so we can use its methods
import sys
import pandas as pd
pd.options.display.float_format = '{:,.3f}'.format
import gamba as gb
# Out:
# gamba ready.

# %%
raw_data = gb.read_csv('/home/ojs/Data/raw_matched_data.csv', ['bet_time','payout_time','duration'])
gb.summarise_app(raw_data)
# Out:
# users: 24234
# games: 5
# num bets: 2232741
# bet value: 2723287.792136176
# payout value: 2688008.0368767725
# start: 2018-08-04 04:27:21 6084746
# end: 2020-03-09 19:32:55 9639151

# %%
df = raw_data

providers = ['dice2win','fck','etheroll']
games = ['coinflip','onedice','twodice','roll']
all_games = []
game_players = []
for provider in providers:
    for game in games:
        game_provider_combo = df[(df['provider'] == provider) & (df['game_type'] == game)]
        if len(game_provider_combo) == 0:
            continue
        all_games.append(game_provider_combo)
        game_players.append(set(game_provider_combo['player_id'].values))
        print('n=', len(set(game_provider_combo['player_id'])), 'b=', len(game_provider_combo))

temp = None
for provider in providers:
    print(provider)
    temp = df[(df['provider'] == provider) & (df['game_type'].isin(games))]
    gb.summarise_app(temp)
# Out:
# n= 5742 b= 702502
# n= 2979 b= 240728
# n= 1633 b= 167759
# n= 3014 b= 416134
# n= 13877 b= 137011
# n= 567 b= 48331
# n= 293 b= 27163
# n= 396 b= 36316
# n= 3086 b= 362324
# dice2win
# users: 7868
# games: 4
# num bets: 1527123
# bet value: 1267239.950539507
# payout value: 1245815.2785478367
# start: 2018-09-07 08:17:21 6287216
# end: 2020-03-09 19:32:55 9639151
#
# fck
# users: 14466
# games: 4
# num bets: 248821
# bet value: 465195.8532056361
# payout value: 462136.7118950764
# start: 2018-12-10 06:05:13 6859200
# end: 2019-07-02 08:49:06 8071084
#
# etheroll
# users: 3086
# games: 1
# num bets: 362324
# bet value: 420942.44164378115
# payout value: 419067.602043743
# start: 2018-08-04 04:27:21 6084746
# end: 2020-03-09 17:35:39 9638617

# %%
# prototype method for summarising collections of dapps in a dataframe (for PLOS)

def summarise_operators(player_bets, operators):
    users = set(player_bets["player_id"].values)
    games = set(player_bets["game_type"].values)
    bets = player_bets["bet_size"].sum()
    payouts = player_bets["payout_size"].sum()
    start_block = player_bets["block_number"].min()
    end_block = player_bets["block_number"].max()
    start = player_bets["bet_time"].min()
    end = player_bets["bet_time"].max()

    summary = pd.DataFrame()
    summary['values'] = ['users', 'games','bet value','payout value','start block','end block','start time','end time']
    summary['fck'] = [users, games, bets, payouts, start_block, end_block, start, end]
    
    return summary

for provider in providers:
    print(provider)
    temp = df[(df['provider'] == provider) & (df['game_type'].isin(games))]
    summarise_dapp(temp, 'n')
# Out:
# etheroll
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d1859a56b987> in <module>
#      18     print(provider)
#      19     temp = df[(df['provider'] == provider) & (df['game_type'].isin(games))]
# ---> 20     summarise_dapp(temp, 'n')
#
# NameError: name 'summarise_dapp' is not defined

# %%
gb.calculate_labrie_measures(raw_data, filename='measures_table.csv', daily=False)
# Out:
#   0%|          | 0/24234 [00:00<?, ?it/s]
# calculating LaBrie measures for 24234 players, this may take some time...
# /home/ojs/Dropbox/phd/code/python/gamba/gamba/measures.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_bets.sort_values("bet_time", inplace=True)
# /home/ojs/Dropbox/phd/code/python/gamba/gamba/measures.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_bets.sort_values("bet_time", inplace=True)
# /home/ojs/Dropbox/phd/code/python/gamba/gamba/measures.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_bets["bet_date"] = player_bets["bet_time"].dt.date
#   3%|▎         | 705/24234 [01:19<44:03,  8.90it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-824b73109501> in <module>
# ----> 1 gb.calculate_labrie_measures(raw_data, filename='measures_table.csv', daily=False)
#
# ~/Dropbox/phd/code/python/gamba/gamba/measures.py in calculate_labrie_measures(all_player_bets, savedir, filename, loud, daily)
#     319
#     320         for i in tqdm(range(len(unique_players))):
# --> 321                 player_bets = all_player_bets[all_player_bets["player_id"] == unique_players[i]]
#     322                 player_id.append(player_bets.iloc[0]["player_id"])
#     323                 all_duration.append(duration(player_bets))
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#     249     else:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      55         result = libops.vec_compare(x.ravel(), y, op)
#      56     else:
# ---> 57         result = libops.scalar_compare(x.ravel(), y, op)
#      58     return result.reshape(x.shape)
#      59
#
# KeyboardInterrupt:

# %%
measures = gb.read_csv('measures_table.csv')

game_measures = []
for players in game_players:
    game_measures.append(measures[measures['player_id'].isin(players)])

labels = ['d2w_f','d2w_d','d2w_2d','d2w_r','fck_f','fck_d','fck_2d','fck_r','eroll']
matrix = gb.calculate_walker_matrix(game_measures, labels, measure='duration')
display(matrix)
# Out:
#          d2w_f   d2w_d  d2w_2d   d2w_r   fck_f   fck_d  fck_2d   fck_r eroll
# d2w_f        -
# d2w_d    0.160       -
# d2w_2d  0.24**   0.100       -
# d2w_r    0.170   0.030   0.080       -
# fck_f   0.55**  0.39**  0.46**  0.39**       -
# fck_d   0.22**  0.08**   0.050   0.050  0.43**       -
# fck_2d   0.4**  0.25**  0.16**  0.23**  0.59**   0.2**       -
# fck_r   0.34**  0.19**   0.1**  0.17**  0.54**  0.13**   0.070       -
# eroll    0.090   0.120  0.19**   0.110  0.49**  0.14**  0.34**  0.27**     -

# %%
# human players are non-fck_flip players
human_df = measures[~measures['player_id'].isin(game_players[4])]
print(len(human_df), human_df['num_bets'].sum())
# Out:
# 10357 1743478

# %%
table = gb.add_tables(gb.descriptive_table(human_df, extended=True), gb.ks_test(human_df))
spearman_coefficient_table = gb.spearmans_r(human_df)
other95, top5 = gb.get_labelled_groups(gb.top_split(human_df, 'total_wagered'), 'top_total_wagered')
print(len(top5), len(other95))
comparison_table = gb.add_tables(gb.descriptive_table(top5, extended=True), gb.descriptive_table(other95, extended=True))
# Out:
# 518 9839

# %%
display(table, spearman_coefficient_table, comparison_table)
# Out:
#                         mean       std  median    iqr  K-S Score     p
# duration              29.695    80.645   1.000 10.000      0.841 0.000
# frequency             76.382    36.450 100.000 50.000      0.966 0.000
# num_bets             168.338   991.976  11.000 62.000      0.841 0.000
# average_bets_per_day  23.126    47.872   6.000 21.000      0.841 0.000
# average_bet_size       1.152    11.811   0.113  0.353      0.504 0.000
# total_wagered        213.770 2,451.852   1.400 16.590      0.504 0.000
# net_loss               2.911    49.864   0.041  0.711      0.213 0.000
# percent_loss          10.913   112.137   5.327 51.991      0.548 0.000
#                      duration frequency num_bets average_bets_per_day  \
# duration                    -
# frequency             -0.89**         -
# num_bets               0.63**   -0.45**        -
# average_bets_per_day   0.35**   -0.19**   0.93**                    -
# average_bet_size       0.16**    -0.1**   0.26**               0.24**
# total_wagered          0.53**   -0.37**   0.84**               0.78**
# net_loss               0.12**    -0.1**   0.15**               0.14**
# percent_loss           -0.1**    0.06**  -0.15**              -0.12**
#
#                      average_bet_size total_wagered net_loss percent_loss
# duration
# frequency
# num_bets
# average_bets_per_day
# average_bet_size                    -
# total_wagered                  0.72**             -
# net_loss                       0.15**         0.2**        -
# percent_loss                  -0.07**       -0.14**   0.67**            -
#                           mean        std  median       iqr   mean     std  \
# duration                95.560    138.375  35.000   120.000 26.227  74.829
# frequency               55.033     35.143  50.000    78.349 77.506  36.172
# num_bets             1,787.716  3,951.361 644.000 1,660.000 83.082 264.546
# average_bets_per_day    90.584     95.034  68.022    77.057 19.575  41.055
# average_bet_size        13.767     50.531   1.841     5.613  0.488   1.960
# total_wagered        3,874.377 10,306.803 986.389 1,759.015 21.048  53.574
# net_loss                38.077    216.264  10.302   102.597  1.059   9.535
# percent_loss             0.947      9.048   0.903     7.598 11.438 115.009
# top_total_wagered        1.000      0.000   1.000     0.000  0.000   0.000
#
#                       median    iqr
# duration               1.000  7.000
# frequency            100.000 50.000
# num_bets               9.000 47.000
# average_bets_per_day   5.000 17.690
# average_bet_size       0.102  0.279
# total_wagered          1.100 10.890
# net_loss               0.039  0.600
# percent_loss           6.556 57.556
# top_total_wagered      0.000  0.000

# %%
gb.ks_test(other95)
# Out:
#                       K-S Score     p
# duration                  0.841 0.000
# frequency                 0.965 0.000
# num_bets                  0.841 0.000
# average_bets_per_day      0.841 0.000
# average_bet_size          0.504 0.000
# total_wagered             0.504 0.000
# net_loss                  0.222 0.000
# percent_loss              0.559 0.000
# top_total_wagered         0.500 0.000

# %%
providers = ['etheroll','fck','dice2win']
provider_labels = ['Etheroll.com','FCK.com','Dice2.Win']
gb.visualise_provider_dates(raw_data, providers, provider_labels = provider_labels)
# Out:
# etheroll
# fck
# dice2win
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-17c4c9cbd60a> in <module>
#       3 providers = ['etheroll','fck','dice2win']
#       4 provider_labels = ['Etheroll.com','FCK.com','Dice2.Win']
# ----> 5 gb.visualise_provider_dates(raw_data, providers, provider_labels = provider_labels)
#
# ~/Dropbox/phd/code/python/gamba/gamba/data.py in visualise_provider_dates(player_bets, providers, provider_labels)
#     455     ax.xaxis.set_major_locator(mdates.MonthLocator([1,4,7,10])) # ticks on first day of each month
#     456     ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y')) # format of only month (3 letter abbr)
# --> 457     if provider_names == None:
#     458         plt.yticks([0,1,2], providers)
#     459     else:
#
# NameError: name 'provider_names' is not defined
